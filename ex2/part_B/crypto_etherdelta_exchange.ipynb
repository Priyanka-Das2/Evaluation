# %%
import json
import pandas as pd
fp = open("ed_tick_sample.json")
data = json.load(fp)
pairs = data.keys()

# %%
pair = pair_iter.next()
pair
# Out:
# u'ETH_ABS'

# %%
pair_data = data[pair]
pair_data.keys()
print pair_data
# Out:
# {u'last': 2.2e-06, u'quoteVolume': 210143.52, u'bid': 1e-07, u'tokenAddr': u'0x7731ee8b0b0ab88977be7922849eb767bbe8da15', u'percentChange': 0.5448, u'ask': 1.875e-06, u'baseVolume': 0.182}

# %%
pair_data
# Out:
# {u'ask': 1.875e-06,
#  u'baseVolume': 0.182,
#  u'bid': 1e-07,
#  u'last': 2.2e-06,
#  u'percentChange': 0.5448,
#  u'quoteVolume': 210143.52,
#  u'tokenAddr': u'0x7731ee8b0b0ab88977be7922849eb767bbe8da15'}

# %%
trade_data1['price'] = trade_data1['price'].astype(float)
trade_data1['bid'] = trade_data1['bid'].astype(float)
trade_data1['ask'] = trade_data1['ask'].astype(float)
trade_data1.to_csv('stack1.csv')

# %%
trade_data = pd.DataFrame(data)

# %%
trade_data
# Out:
#                                                ETH_0x003f  \
# ask                                               1.4e-07
# baseVolume                                              0
# bid                                               1.5e-08
# last                                                5e-09
# percentChange                                       -0.99
# quoteVolume                                         30007
# tokenAddr      0x003f79d7be15dc1ad90ce00e6ea68f335e2b789b
#
#                                                ETH_0x0171  \
# ask                                              6.47e-05
# baseVolume                                          1.044
# bid                                                 1e-05
# last                                             6.49e-05
# percentChange                                      4.2764
# quoteVolume                                         20303
# tokenAddr      0x017188526374f723ec66509ea0c44dd797a33c84
#
# ...
